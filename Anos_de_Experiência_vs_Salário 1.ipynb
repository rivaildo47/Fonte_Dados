# %%
import pandas as pd

# %%
# Criar uma cópia do DataFrame para não modificar o original diretamente se o usuário mudar de ideia
df_cleaned = df_drive.copy()

# Remover todas as linhas que contêm pelo menos um valor NaN
original_rows = len(df_cleaned)
df_cleaned.dropna(inplace=True)
cleaned_rows = len(df_cleaned)

print(f"Número de linhas originais: {original_rows}")
print(f"Número de linhas após remover NaNs: {cleaned_rows}")
print(f"{original_rows - cleaned_rows} linhas foram removidas.\n")

print("Primeiras linhas do DataFrame sem NaNs:")
display(df_cleaned.head())
# Out:
# Número de linhas originais: 40
# Número de linhas após remover NaNs: 34
# 6 linhas foram removidas.
#
# Primeiras linhas do DataFrame sem NaNs:
#    Experience Years   Salary
# 0              11.0  39343.0
# 1              12.0  42774.0
# 2              13.0  46205.0
# 3              15.0  37731.0
# 5              22.0  39891.0

# %%
display(df_drive.head())
# Out:
#    Experience Years   Salary
# 0              11.0  39343.0
# 1              12.0  42774.0
# 2              13.0  46205.0
# 3              15.0  37731.0
# 4               NaN      NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Experience Years', y='Salary', data=df_cleaned)
plt.title('Gráfico de Dispersão: Anos de Experiência vs Salário')
plt.xlabel('Anos de Experiência')
plt.ylabel('Salário')
plt.grid(True)
plt.show()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     831.5
# Date:                Fri, 07 Nov 2025   Prob (F-statistic):           1.80e-24
# Time:                        13:44:49   Log-Likelihood:                -337.91
# No. Observations:                  34   AIC:                             679.8
# Df Residuals:                      32   BIC:                             682.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.572e+04   1946.608     13.212      0.000    2.18e+04    2.97e+04
# ...

# %%
# Criar e ajustar o modelo de regressão linear
model = sm.OLS(Y, X)
results = model.fit()

# Exibir o resumo do modelo
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     831.5
# Date:                Fri, 07 Nov 2025   Prob (F-statistic):           1.80e-24
# Time:                        13:42:17   Log-Likelihood:                -337.91
# No. Observations:                  34   AIC:                             679.8
# Df Residuals:                      32   BIC:                             682.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2.572e+04   1946.608     13.212      0.000    2.18e+04    2.97e+04
# ...

# %%
print("Variável independente (X) com a constante:")
display(X.head())
print("Variável dependente (Y):")
display(Y.head())
# Out:
# Variável independente (X) com a constante:
#    const  Experience Years
# 0    1.0              11.0
# 1    1.0              12.0
# 2    1.0              13.0
# 3    1.0              15.0
# 5    1.0              22.0
# Variável dependente (Y):
# 0    39343.0
# 1    42774.0
# 2    46205.0
# 3    37731.0
# 5    39891.0
# Name: Salary, dtype: float64
